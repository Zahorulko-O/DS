# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению
# <center>
# Автор материала: Юрий Кашницкий, программист-исследователь Mail.Ru Group <br>
#
# Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Домашнее задание № 1 (демо).<br> Анализ данных по доходу населения UCI Adult</center>

# %% [markdown]
# **В задании предлагается с помощью Pandas ответить на несколько вопросов по данным репозитория UCI [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) (качать данные не надо – они уже есть в репозитории).**

# %% [markdown]
# Уникальные значения признаков (больше информации по ссылке выше):
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - salary: >50K,<=50K

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('adult.data.csv')

pd.set_option('precision', 2)
data.head(-1)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
print(data.info())
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
# (32561, 15)

# %% [markdown]
# **1. Сколько мужчин и женщин (признак *sex*) представлено в этом наборе данных?**

# %%
# Ваш код здесь
data['sex'].value_counts(dropna=False)
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %% [markdown]
# **2. Каков средний возраст (признак *age*) женщин?**

# %%
# Ваш код здесь
data.pivot_table(['age'], ['sex'], aggfunc='mean')
# Out:
#           age
# sex
# Female  36.86
# Male    39.43

# %%
print('Female is 36.86')
# Out:
# Female is 36.86

# %% [markdown]
# **3. Какова доля граждан Германии (признак *native-country*)?**

# %%
# Ваш код здесь
d = data['native-country'].value_counts(normalize=True)
print('percent of citizens are Germans is: ', d['Germany']*100, "%")
# Out:
# percent of citizens are Germans is:  0.42074874850281013 %

# %%
print('percent of citizens are Germans: ', 137/32561*100, "%")
# Out:
# percent of citizens are Germans:  0.42074874850281013 %

# %% [markdown]
# **4-5. Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год?**

# %%
# Ваш код здесь

print('Mean value is:\n', data.pivot_table(['age'], ['salary'], aggfunc='mean'))

print('\nStd value is:\n', data.pivot_table(['age'], ['salary'], aggfunc='std'))
# Out:
# Mean value is:
#            age
# salary
# <=50K   36.78
# >50K    44.25
#
# Std value is:
#            age
# salary
# <=50K   14.02
# >50K    10.52

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
tr = {'>50K': 'True', '<=50K': 'False'}
data['salary'] = data['salary'].map(tr)
data
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
data.describe()
age = data.pivot_table(['salary'], ['education'], aggfunc=(np.max))

age
# Out:
#              salary
# education
# 10th           True
# 11th           True
# 12th           True
# 1st-4th        True
# 5th-6th        True
# 7th-8th        True
# 9th            True
# Assoc-acdm     True
# Assoc-voc      True
# Bachelors      True
# Doctorate      True
# HS-grad        True
# Masters        True
# Preschool     False
# Prof-school    True
# Some-college   True

# %%
No

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Amer-Indian-Eskimo*.**

# %%
#Amer-Indian-Eskimo
data.describe()
age = data.pivot_table(['age'], ['race', 'sex'], aggfunc='max')
age
# Out:
#                            age
# race               sex
# Amer-Indian-Eskimo Female   80
#                    Male     82
# Asian-Pac-Islander Female   75
#                    Male     90
# Black              Female   90
#                    Male     90
# Other              Female   74
#                    Male     77
# White              Female   90
#                    Male     90

# %%
data.describe(include='all') #all statistics
# Out:
#           age workclass  fnlwgt education  education-num      marital-status  \
# count   32561     32561   3e+04     32561          32561               32561
# unique    NaN         9     NaN        16            NaN                   7
# top       NaN   Private     NaN   HS-grad            NaN  Married-civ-spouse
# freq      NaN     22696     NaN     10501            NaN               14976
# mean       39       NaN   2e+05       NaN             10                 NaN
# std        14       NaN   1e+05       NaN              3                 NaN
# min        17       NaN   1e+04       NaN              1                 NaN
# 25%        28       NaN   1e+05       NaN              9                 NaN
# 50%        37       NaN   2e+05       NaN             10                 NaN
# 75%        48       NaN   2e+05       NaN             12                 NaN
# max        90       NaN   1e+06       NaN             16                 NaN
#
# ...

# %%
data.groupby(by=['race',  'sex'])['age'].agg([np.max])
# Out:
#                            amax
# race               sex
# Amer-Indian-Eskimo Female    80
#                    Male      82
# Asian-Pac-Islander Female    75
#                    Male      90
# Black              Female    90
#                    Male      90
# Other              Female    74
#                    Male      77
# White              Female    90
#                    Male      90

# %%
print("Max age Amer-Indian-Eskimos male is: 82")
# Out:
# Max age Amer-Indian-Eskimos male is: 82

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
# Ваш код здесь
data['N'] = 1
marital = {'Married-civ-spouse': 1, 'Married-spouse-absent': 1, 'Married-AF-spouse': 1, 
           'Divorced': 0, 'Never-married': 0, 'Widowed': 0, 'Separated': 0}  # 1 - женатыe; 0 - холостые

data['marital-status'] = data['marital-status'].map(marital)
#data
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
d1 = data.drop(['age', 'workclass', 'fnlwgt', 'education', 'education-num', 
                'occupation', 'relationship', 'race', 'sex', 
                'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'], axis=1)

a = d1[(d1['marital-status'] == 1) & (d1['salary'] == 'True')]['N'].sum() #женатыe
b = d1[(d1['marital-status'] == 0) & (d1['salary'] == 'True')]['N'].sum() #холостые

#print(' Среди кого больше доля зарабатывающих много: ', np.where(a>b, "женатыx", "холостыx"))
print("Among whom there is more than a lot of earners: ", np.where(a>b,"married", "single"))
# Out:
# Among whom there is more than a lot of earners:  married

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
# Ваш код здесь
a = (data['hours-per-week'].max()) #максимальное число часов человек работает в неделю
print("maximum number of hours a person works per week: ", a)
# Out:
# maximum number of hours a person works per week:  99

# %%
data[data['hours-per-week'] == 99]

d2 = data.drop(['age', 'workclass', 'fnlwgt', 'education', 'education-num', 
               'marital-status', 'occupation', 'relationship', 'race', 'sex', 
              'capital-gain', 'capital-loss', 'native-country', ], axis=1)

d2.sort_values(by=['hours-per-week', 'salary'], ascending=[False, True]).head(100) #сортирую по убыванию максимальное число часов
#все, кто работает мах(99):
A = d2[(d2['hours-per-week'] == 99)]['N'].sum() 
# работает мах(99) и зарабатывает много:
B = d2[(d2['hours-per-week'] == 99) & (d2['salary'] == 'True')]['N'].sum()

# %%
print("percentage of those who earn a lot: ", round(B/A*100, 3), "%" )
# Out:
# percentage of those who earn a lot:  29.412 %

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
data.head(-1)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
# Ваш код здесь

new = data.pivot_table(['hours-per-week'], ['salary', 'native-country'], aggfunc='mean')
new
# Out:
#                                    hours-per-week
# salary native-country
# False  ?                                    40.16
#        Cambodia                             41.42
#        Canada                               37.91
#        China                                37.38
#        Columbia                             38.68
#        Cuba                                 37.99
#        Dominican-Republic                   42.34
#        Ecuador                              38.04
#        El-Salvador                          36.03
#        England                              40.48
#        France                               41.06
#        Germany                              39.14
#        Greece                               41.81
#        Guatemala                            39.36
#        Haiti                                36.33
#        Holand-Netherlands                   40.00
#        Honduras                             34.33
# ...

# %%
get_ipython().system('jupyter nbconvert --to script topic1_habr_pandas.ipynb')
# Out:
# [NbConvertApp] Converting notebook topic1_habr_pandas.ipynb to script
# [NbConvertApp] Writing 14988 bytes to topic1_habr_pandas.py
